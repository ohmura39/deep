# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# 正規分布に従う連続型確率変数を1000個生成
# 正規分布のパラメータ
mu = 0 # 平均
sigma = 1 # 標準偏差

x = np.random.normal(mu, sigma, 1000)

# ヒストグラムで表示
plt.hist(x, bins=20, density=True)
plt.title("Normal distribution")
plt.xlabel("x")
plt.ylabel("Probability density")
plt.show()

# %%
from scipy.stats import norm

# %%
data = norm.rvs(loc=10, scale=2, size=1000)

# %%
plt.hist(data, bins=20, density=True)
# Out:
# (array([0.00163607, 0.00163607, 0.01308857, 0.01963285, 0.03108534,
#         0.06871497, 0.07525925, 0.13252173, 0.17669563, 0.18814813,
#         0.19632848, 0.18651206, 0.1505185 , 0.13252173, 0.10961674,
#         0.06053462, 0.04580998, 0.02290499, 0.01472464, 0.00818035]),
#  array([ 3.51118761,  4.12240814,  4.73362867,  5.34484921,  5.95606974,
#          6.56729028,  7.17851081,  7.78973134,  8.40095188,  9.01217241,
#          9.62339294, 10.23461348, 10.84583401, 11.45705455, 12.06827508,
#         12.67949561, 13.29071615, 13.90193668, 14.51315722, 15.12437775,
#         15.73559828]),
#  <BarContainer object of 20 artists>)

# %%
x = np.linspace(0, 20, 100)
y = norm.pdf(x, loc=10, scale=2)
plt.plot(x, y)
